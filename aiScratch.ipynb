# %% [markdown]
# <a href="https://colab.research.google.com/github/majidalobaidi/ai-engineering-from-scratch/blob/my-progress/aiScratch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install tensorflow

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
import numpy as np
data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# (np.float64(0.018760171444496224), np.float64(1.0359241141534394))

# %%
import numpy as np
data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# (np.float64(-0.006468406362182585), np.float64(1.0137446610227443))

# %%
# %pip install numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\mosha\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import numpy as np
data = np.random.randn(1000)
data.mean(), data.std()
# Out:
# (np.float64(0.005337087902098789), np.float64(0.978539132246241))

# %%
# %timeit np.random.randn(10000)
# Out:
# 297 μs ± 80.1 ns per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# 1. You must define the model first!
model = Sequential([
    Dense(64, activation='relu'),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')

# %%
import numpy as np

# Create dummy training data (1000 samples, 20 features each)
X_train = np.random.randn(1000, 20)
y_train = np.random.randn(1000, 1)

# %%
# %%time
model.fit(X_train, y_train, epochs=10)
# Out:
# Epoch 1/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - loss: 1.2257
# Epoch 2/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - loss: 1.1198
# Epoch 3/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0785
# Epoch 4/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0494
# Epoch 5/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0271
# Epoch 6/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 1.0095
# Epoch 7/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9876
# Epoch 8/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9722
# Epoch 9/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 0.9569
# Epoch 10/10
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - loss: 0.9421
# CPU times: total: 6.38 s
# Wall time: 6.74 s

# %%
import sys
print(sys.version)

# %%
jupyter notebook
# Out:
#   Cell In[1], line 1
#     jupyter notebook
#             ^
# SyntaxError: invalid syntax

# %%
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 get_ipython().run_line_magic('matplotlib', 'inline')
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# %pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/8.2 MB ? eta -:--:--
#    ----------------------------------- ---- 7.3/8.2 MB 37.8 MB/s eta 0:00:01
#    ---------------------------------------- 8.2/8.2 MB 34.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 33.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/7.1 MB ? eta -:--:--
#    ---------------------------------------- 7.1/7.1 MB 39.7 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: The scripts fonttools.exe, pyftmerge.exe, pyftsubset.exe and ttx.exe are installed in 'C:\Users\mosha\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\Scripts' which is not on PATH.
# ...

# %%
# %matplotlib inline
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# !pip install scikit-learn
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    --------------------------------- ------ 6.8/8.1 MB 40.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 36.4 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/37.3 MB ? eta -:--:--
#    ----------- ---------------------------- 10.5/37.3 MB 49.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 20.7/37.3 MB 49.2 MB/s eta 0:00:01
#    -------------------------------- ------- 30.7/37.3 MB 49.3 MB/s eta 0:00:01
#    ---------------------------------------  37.2/37.3 MB 50.2 MB/s eta 0:00:01
#    ---------------------------------------- 37.3/37.3 MB 44.7 MB/s  0:00:00
# ...
#
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
#    ---------- ----------------------------- 1/4 [scipy]
# ...

# %%
# %pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached tzdata-2026.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/9.8 MB ? eta -:--:--
#    --------------------------------- ------ 8.1/9.8 MB 45.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.8/9.8 MB 40.6 MB/s eta 0:00:00
# Using cached tzdata-2026.2-py2.py3-none-any.whl (349 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 26.1.2
# [notice] To update, run: C:\Users\mosha\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import pandas as pd

df = pd.DataFrame({
    "model": ["Linear", "Random Forest", "Neural Net"],
    "accuracy": [0.72, 0.89, 0.94],
    "training_time": [0.1, 2.3, 45.6]
})
df
# Out:
#            model  accuracy  training_time
# 0         Linear      0.72            0.1
# 1  Random Forest      0.89            2.3
# 2     Neural Net      0.94           45.6

# %%
# %env CUDA_VISIBLE_DEVICES=-1
# Out:
# env: CUDA_VISIBLE_DEVICES=-1

# %%
# %env
# Out:
# {'ALLUSERSPROFILE': 'C:\\ProgramData',
#  'APPDATA': 'C:\\Users\\mosha\\AppData\\Roaming',
#  'COMMONPROGRAMFILES': 'C:\\Program Files\\Common Files',
#  'COMMONPROGRAMFILES(X86)': 'C:\\Program Files (x86)\\Common Files',
#  'COMMONPROGRAMW6432': 'C:\\Program Files\\Common Files',
#  'COMPUTERNAME': 'MUNTAHA',
#  'COMSPEC': 'C:\\WINDOWS\\system32\\cmd.exe',
#  'DRIVERDATA': 'C:\\Windows\\System32\\Drivers\\DriverData',
#  'HOMEDRIVE': 'C:',
#  'HOMEPATH': '\\Users\\mosha',
#  'IPY_INTERRUPT_EVENT': '1668',
#  'JPY_INTERRUPT_EVENT': '1668',
#  'JPY_PARENT_PID': '928',
#  'JPY_SESSION_NAME': 'C:\\WINDOWS\\system32\\Untitled.ipynb',
#  'LOCALAPPDATA': 'C:\\Users\\mosha\\AppData\\Local',
#  'LOGONSERVER': '\\\\MUNTAHA',
#  'NUMBER_OF_PROCESSORS': '16',
#  'ONEDRIVE': 'C:\\Users\\mosha\\OneDrive',
#  'ONEDRIVECONSUMER': 'C:\\Users\\mosha\\OneDrive',
#  'OS': 'Windows_NT',
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 4))
plt.plot([1, 2, 3, 4], [1, 4, 2, 3])
plt.title("Inline Plot")
plt.show()

# %%
from IPython.display import Image, display
display(Image(filename="architecture.png"))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[24], line 2
#       1 from IPython.display import Image, display
# ----> 2 display(Image(filename="architecture.png"))
#
# FileNotFoundError: [Errno 2] No such file or directory: 'architecture.png'
